# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm
import seaborn as sns
from scipy.stats import norm

# %%
norm.cdf(x = 3, loc = 0 ,scale =1.0)
# Out:
# np.float64(0.9986501019683699)

# %%
np.random.randn(3,3)
# Out:
# array([[-0.6451767 ,  0.62791232, -0.21129298],
#        [ 0.71579752, -0.43864899, -0.69678256],
#        [ 0.19543895,  0.65922504,  0.07769548]])
